# %% [markdown]
# # Prepare data from pse.pl for use in ML

# %%
import os
import pandas as pd
import numpy as np
import time
from datetime import datetime
from datetime import timedelta
import itertools

import warnings

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 300)
pd.set_option('display.max_colwidth', None)

PATH_TGE='../../data/tge/'

# %% [markdown]
# # Read data

# %%
# %%time
df_tge=pd.read_parquet(f'{PATH_TGE}tge_full.parquet')
df_b_moc=pd.read_parquet(f'{PATH_TGE}b_moc.parquet')
df_g_moc=pd.read_parquet(f'{PATH_TGE}g_moc.parquet')
df_g_wiatr=pd.read_parquet(f'{PATH_TGE}g_wiatr.parquet')
df_i_net=pd.read_parquet(f'{PATH_TGE}i_net.parquet')
df_w_kse=pd.read_parquet(f'{PATH_TGE}w_kse.parquet')
df_w_ubytki=pd.read_parquet(f'{PATH_TGE}w_ubytki.parquet')
df_w_wym=pd.read_parquet(f'{PATH_TGE}w_wym.parquet')
df_weather_ml=pd.read_parquet(f'{PATH_TGE}weather_ml.parquet')
df_z_kse=pd.read_parquet(f'{PATH_TGE}z_kse.parquet')
# Out:
# CPU times: total: 1.97 s
# Wall time: 1.09 s

# %% [markdown]
# # Function

# %%
def create_datetime(d,f,h=0):
    if h==0:
        return datetime.strptime(str(d), f)
    else:
        return datetime.strptime(str(d), f) + timedelta(hours=(h-1))

# %%
def info_dataset(df):
    print(f'Count rows: {df.shape}')
    print(f'Min date: {df.index.min()}')
    print(f'Max date: {df.index.max()}')

# %%
def check_missing_datetime_index(df,resize='H'):
    if df.index.size != df.resample(resize).mean().index.size:
        print("There are missing dates in the datetime index.")
        df_err=df.resample(resize).mean()
        return df_err[df_err.isnull().any(1)]
    else:
        print("There are no missing dates in the datetime index.")

# %%
def prepare_column(df,list_col):
    df=df[df['Godzina']!='2A']
    df['Godzina']=df['Godzina'].astype(int)
    df['Data']=df['Data'].astype(str)
    for x in list_col:
        df[x]=np.where(df[x].isna(),0,df[x].str.replace(',','.').replace('-','0').astype(float))
    return df

def prepare_index(df,date_format):
    df['date_hour']=df.apply(lambda x:create_datetime(x.Data,date_format,x.Godzina), axis=1)
    df.index=df['date_hour']
    df.drop(['Data','Godzina','date_hour'],axis=1,inplace=True)
    warnings.filterwarnings("ignore")
    df_res=check_missing_datetime_index(df,'H')
    print(f'count row with missing index: {len(df_res)}')
    df=df.resample('H').mean().fillna(method='backfill')
    return df

# %%
#df_date=pd.DataFrame(pd.date_range(start='2016-01-01', end='2023-01-01', freq="1H"), columns=['date_time'])

# %% [markdown]
# # Prepare TGE

# %%
df_tge['fixing_1_kurs']=df_tge['fixing_1_kurs'].replace(0, np.nan).fillna(method='backfill')
df_tge.head()
# Out:
#                            date  czas  fixing_1_kurs  fixing_1_wolumen  \
# date_hour
# 2019-06-28 00:00:00  2019-06-28     1         220.54            1754.3
# 2019-06-28 01:00:00  2019-06-28     2         203.85            1674.0
# 2019-06-28 02:00:00  2019-06-28     3         203.85            1786.2
# 2019-06-28 03:00:00  2019-06-28     4         203.85            1689.4
# 2019-06-28 04:00:00  2019-06-28     5         203.85            1793.9
#
#                      fixing_2_kurs  fixing_2_wolumen  notowania_kurs  \
# date_hour
# 2019-06-28 00:00:00         226.53            1245.7             0.0
# 2019-06-28 01:00:00         191.84            1277.3             0.0
# 2019-06-28 02:00:00         201.12            1079.6             0.0
# 2019-06-28 03:00:00         211.05             844.5             0.0
# 2019-06-28 04:00:00         222.50             602.3             0.0
#
#                      notowania_wolumen           date_hour
# date_hour
# 2019-06-28 00:00:00                5.0 2019-06-28 00:00:00
# 2019-06-28 01:00:00                0.0 2019-06-28 01:00:00
# 2019-06-28 02:00:00                0.0 2019-06-28 02:00:00
# 2019-06-28 03:00:00                0.0 2019-06-28 03:00:00
# 2019-06-28 04:00:00                0.0 2019-06-28 04:00:00

# %%
info_dataset(df_tge)
# Out:
# Count rows: (29328, 9)
# Min date: 2019-06-28 00:00:00
# Max date: 2022-10-31 23:00:00

# %% [markdown]
# # Prepare b_moc

# %%
df_b_moc['date_hour']=df_b_moc.apply(lambda x:create_datetime(x.Data,"%Y%m%d"), axis=1)

for x in df_b_moc.drop(['Data','date_hour','Kwadrans szczytowy (typ)','Kwadrans szczytowy'],axis=1).columns.to_list():
    df_b_moc[x]=df_b_moc[x].str.replace(',','.')
    df_b_moc[x]=df_b_moc[x].str.replace(u'\xa0','').astype(float)
dfbm=df_b_moc.drop(['Kwadrans szczytowy (typ)','Kwadrans szczytowy','Data'],axis=1).groupby('date_hour').mean().reset_index()
dfbm.index=dfbm['date_hour']
dfbm.drop(['date_hour'],axis=1,inplace=True)
dfbm.head()
# Out:
#             Moc osi¹galna elektrowni krajowych  Elektrownie zawodowe     JWCD  \
# date_hour
# 2016-01-01                            39535.15              37084.35  24901.0
# 2016-01-02                            39535.15              37084.35  24901.0
# 2016-01-03                            39535.15              37084.35  24901.0
# 2016-01-04                            39535.15              37084.35  24901.0
# 2016-01-05                            39535.15              37084.35  24901.0
#
#             pozosta³e  elektrownie przemys³owe  \
# date_hour
# 2016-01-01   12183.35                   2450.8
# 2016-01-02   12183.35                   2450.8
# 2016-01-03   12183.35                   2450.8
# 2016-01-04   12183.35                   2450.8
# 2016-01-05   12183.35                   2450.8
#
#             Ubytki mocy elektrowni przemys³owych  \
# date_hour
# 2016-01-01                               1144.20
# 2016-01-02                               1127.35
# 2016-01-03                               1188.80
# 2016-01-04                               1191.95
# 2016-01-05                               1157.65
#
#             Ubytki mocy elektrowni zawodowych  \
# date_hour
# 2016-01-01                            8661.69
# 2016-01-02                            6707.09
# 2016-01-03                            9440.44
# 2016-01-04                            9150.74
# 2016-01-05                           10948.54
#
#             spowodowane remontami kapitalnymi  JWCD.1  pozosta³e.1  \
# date_hour
# 2016-01-01                             1351.9  1155.0        196.9
# 2016-01-02                             1351.9  1155.0        196.9
# 2016-01-03                             1351.9  1155.0        196.9
# 2016-01-04                             1376.9  1180.0        196.9
# 2016-01-05                             1376.9  1180.0        196.9
#
#             spowodowane remontami rednimi  JWCD.2  pozosta³e.2  \
# date_hour
# 2016-01-01                           231.3   225.0          6.3
# 2016-01-02                           231.3   225.0          6.3
# 2016-01-03                           231.3   225.0          6.3
# 2016-01-04                           231.3   225.0          6.3
# 2016-01-05                           231.3   225.0          6.3
#
#             spowodowane remontami bie¿¹cymi  JWCD.3  pozosta³e.3  \
# date_hour
# 2016-01-01                            273.0   225.0         48.0
# 2016-01-02                            273.0   225.0         48.0
# 2016-01-03                            498.0   450.0         48.0
# 2016-01-04                            273.0   225.0         48.0
# 2016-01-05                            290.2   225.0         65.2
#
#             spowodowane remontami awaryjnymi  JWCD.4  pozosta³e.4  \
# date_hour
# 2016-01-01                             453.0   179.0        274.0
# 2016-01-02                             485.3   205.0        280.3
# 2016-01-03                            1288.4   931.3        357.1
# 2016-01-04                            1235.2   825.9        409.3
# 2016-01-05                            1090.8   686.0        404.8
#
#             spowodowane warunkami eksploatacyjnymi   JWCD.5  pozosta³e.5  \
# date_hour
# 2016-01-01                                 5444.06   570.00      4874.06
# 2016-01-02                                 3335.71   610.00      2725.71
# 2016-01-03                                 5007.66   764.50      4243.16
# 2016-01-04                                 5049.36   862.05      4187.31
# 2016-01-05                                 6994.81  1749.05      5245.76
#
#             ze wzglêdu na ciep³ownictwo  JWCD.6  pozosta³e.6  \
# date_hour
# 2016-01-01                       908.43    8.30       900.13
# 2016-01-02                      1029.88   35.80       994.08
# 2016-01-03                      1063.18   74.25       988.93
# 2016-01-04                       984.98   77.90       907.08
# 2016-01-05                       964.53   63.30       901.23
#
#             na JW bedacych w okresie oswajania z inwestycji  JWCD.7  \
# date_hour
# 2016-01-01                                              0.0     0.0
# 2016-01-02                                              0.0     0.0
# 2016-01-03                                              0.0     0.0
# 2016-01-04                                              0.0     0.0
# 2016-01-05                                              0.0     0.0
#
#             pozosta³e.7  Moc dyspozycyjna elektrowni krajowych  \
# date_hour
# 2016-01-01          0.0                               29733.56
# 2016-01-02          0.0                               31716.41
# 2016-01-03          0.0                               28940.06
# 2016-01-04          0.0                               29217.41
# 2016-01-05          0.0                               27473.46
#
#             elektrownie zawodowe    JWCD.8  pozosta³e.8  \
# date_hour
# 2016-01-01              28426.96  22542.10      5884.86
# 2016-01-02              30392.96  22452.85      7940.11
# 2016-01-03              27678.06  21334.45      6343.61
# 2016-01-04              27958.56  21528.15      6430.41
# 2016-01-05              26180.31  20802.65      5377.66
#
#             elektrownie przemys³owe.1  Obci¹¿enie elektrowni krajowych  \
# date_hour
# 2016-01-01                    1306.60                         16518.20
# 2016-01-02                    1323.45                         19539.05
# 2016-01-03                    1262.00                         20120.00
# 2016-01-04                    1258.85                         24929.00
# 2016-01-05                    1293.15                         24646.15
#
#             elektrownie zawodowe.1    JWCD.9  pozosta³e.9  \
# date_hour
# 2016-01-01                15211.60   9658.20      5553.40
# 2016-01-02                18215.60  10604.00      7611.60
# 2016-01-03                18858.00  12863.35      5994.65
# 2016-01-04                23670.15  17541.05      6129.10
# 2016-01-05                23353.00  18298.60      5054.40
#
#             elektrownie przemys³owe.2  Krajowe zapotrzebowanie na moc  \
# date_hour
# 2016-01-01                    1306.60                      16662.5260
# 2016-01-02                    1323.45                      19683.1585
# 2016-01-03                    1262.00                      19792.1700
# 2016-01-04                    1258.85                      24590.0335
# 2016-01-05                    1293.15                      24761.0710
#
#             Krajowe saldo wymiany miêdzysystemowej *  \
# date_hour
# 2016-01-01                                    150.05
# 2016-01-02                                    141.20
# 2016-01-03                                   -322.30
# 2016-01-04                                   -348.35
# 2016-01-05                                    112.85
#
#             Ubytki mocy z uwagi na warunki pracy sieci  \
# date_hour
# 2016-01-01                                         0.0
# 2016-01-02                                       112.0
# 2016-01-03                                       112.0
# 2016-01-04                                       112.0
# 2016-01-05                                         0.0
#
#             Rezerwa mocy w elektrowniach zawodowych:**  Rezerwa mocy w JWCD  \
# date_hour
# 2016-01-01                                    13215.36             12883.90
# 2016-01-02                                    12065.36             11736.85
# 2016-01-03                                     8708.06              8359.10
# 2016-01-04                                     4176.41              3875.10
# 2016-01-05                                     2827.31              2504.05
#
#             JWCD cieplne:  rezerwa wiruj¹ca  rezerwa zimna  JWCD wodne  \
# date_hour
# 2016-01-01       11509.85           2258.85         9251.0     1374.05
# 2016-01-02       10338.50           2131.00         8207.5     1398.35
# 2016-01-03        7188.40            340.60         6847.8     1170.70
# 2016-01-04        2506.50           1081.20         1425.3     1368.60
# 2016-01-05        1239.40           1216.90           22.5     1264.65
#
#             Rezerwa mocy pozosta³a
# date_hour
# 2016-01-01                  331.46
# 2016-01-02                  328.51
# 2016-01-03                  348.96
# 2016-01-04                  301.31
# 2016-01-05                  323.26

# %%
warnings.filterwarnings("ignore")
df_res=check_missing_datetime_index(dfbm,'D')
df_res
# Out:
# There are no missing dates in the datetime index.

# %%
info_dataset(dfbm)
# Out:
# Count rows: (2496, 48)
# Min date: 2016-01-01 00:00:00
# Max date: 2022-10-31 00:00:00

# %%
dfbm.resample('H').ffill()[:2]
# Out:
#                      Moc osi¹galna elektrowni krajowych  Elektrownie zawodowe  \
# date_hour
# 2016-01-01 00:00:00                            39535.15              37084.35
# 2016-01-01 01:00:00                            39535.15              37084.35
#
#                         JWCD  pozosta³e  elektrownie przemys³owe  \
# date_hour
# 2016-01-01 00:00:00  24901.0   12183.35                   2450.8
# 2016-01-01 01:00:00  24901.0   12183.35                   2450.8
#
#                      Ubytki mocy elektrowni przemys³owych  \
# date_hour
# 2016-01-01 00:00:00                                1144.2
# 2016-01-01 01:00:00                                1144.2
#
#                      Ubytki mocy elektrowni zawodowych  \
# date_hour
# 2016-01-01 00:00:00                            8661.69
# 2016-01-01 01:00:00                            8661.69
#
#                      spowodowane remontami kapitalnymi  JWCD.1  pozosta³e.1  \
# date_hour
# 2016-01-01 00:00:00                             1351.9  1155.0        196.9
# 2016-01-01 01:00:00                             1351.9  1155.0        196.9
#
#                      spowodowane remontami rednimi  JWCD.2  pozosta³e.2  \
# date_hour
# 2016-01-01 00:00:00                           231.3   225.0          6.3
# 2016-01-01 01:00:00                           231.3   225.0          6.3
#
#                      spowodowane remontami bie¿¹cymi  JWCD.3  pozosta³e.3  \
# date_hour
# 2016-01-01 00:00:00                            273.0   225.0         48.0
# 2016-01-01 01:00:00                            273.0   225.0         48.0
#
#                      spowodowane remontami awaryjnymi  JWCD.4  pozosta³e.4  \
# date_hour
# 2016-01-01 00:00:00                             453.0   179.0        274.0
# 2016-01-01 01:00:00                             453.0   179.0        274.0
#
#                      spowodowane warunkami eksploatacyjnymi  JWCD.5  \
# date_hour
# 2016-01-01 00:00:00                                 5444.06   570.0
# 2016-01-01 01:00:00                                 5444.06   570.0
#
#                      pozosta³e.5  ze wzglêdu na ciep³ownictwo  JWCD.6  \
# date_hour
# 2016-01-01 00:00:00      4874.06                       908.43     8.3
# 2016-01-01 01:00:00      4874.06                       908.43     8.3
#
#                      pozosta³e.6  \
# date_hour
# 2016-01-01 00:00:00       900.13
# 2016-01-01 01:00:00       900.13
#
#                      na JW bedacych w okresie oswajania z inwestycji  JWCD.7  \
# date_hour
# 2016-01-01 00:00:00                                              0.0     0.0
# 2016-01-01 01:00:00                                              0.0     0.0
#
#                      pozosta³e.7  Moc dyspozycyjna elektrowni krajowych  \
# date_hour
# 2016-01-01 00:00:00          0.0                               29733.56
# 2016-01-01 01:00:00          0.0                               29733.56
#
#                      elektrownie zawodowe   JWCD.8  pozosta³e.8  \
# date_hour
# 2016-01-01 00:00:00              28426.96  22542.1      5884.86
# 2016-01-01 01:00:00              28426.96  22542.1      5884.86
#
#                      elektrownie przemys³owe.1  \
# date_hour
# 2016-01-01 00:00:00                     1306.6
# 2016-01-01 01:00:00                     1306.6
#
#                      Obci¹¿enie elektrowni krajowych  elektrownie zawodowe.1  \
# date_hour
# 2016-01-01 00:00:00                          16518.2                 15211.6
# 2016-01-01 01:00:00                          16518.2                 15211.6
#
#                      JWCD.9  pozosta³e.9  elektrownie przemys³owe.2  \
# date_hour
# 2016-01-01 00:00:00  9658.2       5553.4                     1306.6
# 2016-01-01 01:00:00  9658.2       5553.4                     1306.6
#
#                      Krajowe zapotrzebowanie na moc  \
# date_hour
# 2016-01-01 00:00:00                       16662.526
# 2016-01-01 01:00:00                       16662.526
#
#                      Krajowe saldo wymiany miêdzysystemowej *  \
# date_hour
# 2016-01-01 00:00:00                                    150.05
# 2016-01-01 01:00:00                                    150.05
#
#                      Ubytki mocy z uwagi na warunki pracy sieci  \
# date_hour
# 2016-01-01 00:00:00                                         0.0
# 2016-01-01 01:00:00                                         0.0
#
#                      Rezerwa mocy w elektrowniach zawodowych:**  \
# date_hour
# 2016-01-01 00:00:00                                    13215.36
# 2016-01-01 01:00:00                                    13215.36
#
#                      Rezerwa mocy w JWCD  JWCD cieplne:  rezerwa wiruj¹ca  \
# date_hour
# 2016-01-01 00:00:00              12883.9       11509.85           2258.85
# 2016-01-01 01:00:00              12883.9       11509.85           2258.85
#
#                      rezerwa zimna  JWCD wodne  Rezerwa mocy pozosta³a
# date_hour
# 2016-01-01 00:00:00         9251.0     1374.05                  331.46
# 2016-01-01 01:00:00         9251.0     1374.05                  331.46

# %% [markdown]
# # Prepare g_moc
#
# - Doba="20220101", Data publikacji="20220102122138"

# %%
# %%time
df_g_moc['kod_tryb']=df_g_moc['Tryb pracy'].map(lambda x: x[:3])+'_'+df_g_moc['Kod'].map(lambda x: x[:3])
df_g_moc.drop(['Data publikacji','Kod','Nazwa','Tryb pracy'],axis=1,inplace=True)

for x in df_g_moc.drop(['Doba','kod_tryb','2'],axis=1).columns.to_list():
    df_g_moc[x]=df_g_moc[x].str.replace(',','.')
    df_g_moc[x]=df_g_moc[x].str.replace(u'\xa0','').astype(float)
df_g_moc['2']=np.where(df_g_moc['2'].isna(),(df_g_moc['1']+df_g_moc['3'])/2,df_g_moc['2'].str.replace(',','.').astype(float))

col=list(set(df_g_moc.columns.to_list())-set(['Doba','kod_tryb']))
dfgm=pd.melt(df_g_moc, id_vars=['Doba','kod_tryb'], value_vars=col)
dfgm['variable']=dfgm['variable'].astype(int)

df_pt=pd.pivot_table(dfgm, values='value', index=['Doba','variable'],columns='kod_tryb', aggfunc=np.sum, fill_value=0, margins=False)#.reset_index()
df_pt.columns = [''.join(str(s).strip() for s in col if s) for col in df_pt.columns ]
df_pt=df_pt.reset_index()

df_pt['Doba']=df_pt['Doba'].astype(str)
df_pt['date_hour']=df_pt.apply(lambda x:create_datetime(x.Doba, "%Y%m%d", x.variable), axis=1)
df_pt.index=df_pt['date_hour']
df_pt.drop(['Doba','variable'],axis=1,inplace=True)
df_pt.head()
# Out:
# CPU times: total: 6.53 s
# Wall time: 6.54 s
#                      Gen_ADM  Gen_BEL  Gen_CHZ  Gen_DCH  Gen_DOD  Gen_JW2  \
# date_hour
# 2018-01-01 00:00:00        0  1738.76  150.055      0.0   271.15      0.0
# 2018-01-01 01:00:00        0  1568.03  150.154      0.0   256.57      0.0
# 2018-01-01 02:00:00        0  1451.86  149.955      0.0   245.93      0.0
# 2018-01-01 03:00:00        0  1374.38  150.059      0.0   254.71      0.0
# 2018-01-01 04:00:00        0  1398.97  150.054      0.0   256.73      0.0
#
#                      Gen_JW3  Gen_KAR  Gen_KAT  Gen_KLE  Gen_KOZ  Gen_LD4  \
# date_hour
# 2018-01-01 00:00:00    147.7  107.765   88.217  141.434   631.68     55.1
# 2018-01-01 01:00:00    143.5  107.260   88.137  125.224   717.15     55.4
# 2018-01-01 02:00:00    139.1  107.365   88.255  123.499   725.39     55.1
# 2018-01-01 03:00:00    145.7  107.024   88.187  123.570   613.33     55.1
# 2018-01-01 04:00:00    146.1  108.595   88.024  123.130   639.64     55.4
#
#                      Gen_LEC  Gen_LGA  Gen_LZA  Gen_OPL  Gen_OSB  Gen_PAT  \
# date_hour
# 2018-01-01 00:00:00  120.945     71.9   284.39   409.21   160.64   446.47
# 2018-01-01 01:00:00  120.780     71.9   304.22   390.62   153.16   446.77
# 2018-01-01 02:00:00  120.835     71.7   211.76   375.77   148.28   439.85
# 2018-01-01 03:00:00  120.945     71.9   246.66   388.09   152.09   435.29
# 2018-01-01 04:00:00  120.945     71.9   296.27   390.97   152.57   441.80
#
#                      Gen_PLO  Gen_POL  Gen_PZR  Gen_REC  Gen_RYB  Gen_SIA  \
# date_hour
# 2018-01-01 00:00:00      0.0   373.57     35.3   82.803   401.72     71.9
# 2018-01-01 01:00:00      0.0   377.51      1.4   82.324   419.22     72.4
# 2018-01-01 02:00:00      0.0   368.20      0.0   82.238   414.04     73.4
# 2018-01-01 03:00:00      0.0   340.43      0.0   82.205   420.72     72.3
# 2018-01-01 04:00:00      0.0   364.01      0.0   82.183   422.65     72.3
#
#                      Gen_SNA  Gen_SOL  Gen_STW  Gen_TUR  Gen_WLC  Gen_WRO  \
# date_hour
# 2018-01-01 00:00:00    68.50      0.0      0.0   520.35      0.0    120.2
# 2018-01-01 01:00:00    68.20      0.0      0.0   500.62      0.0    112.7
# 2018-01-01 02:00:00    69.34      0.0      0.0   482.66      0.0    113.0
# 2018-01-01 03:00:00    67.39      0.0      0.0   510.62      0.0    111.6
# 2018-01-01 04:00:00    67.39      0.0      0.0   513.57      0.0    107.1
#
#                      Gen_WSI  Gen_WZE  Gen_ZGR  Gen_ZRN  Gen_ZYD  Pom_DCH  \
# date_hour
# 2018-01-01 00:00:00    360.0      0.0    98.58      0.0      0.0      0.0
# 2018-01-01 01:00:00    292.0      0.0    98.46      0.0      0.0      0.0
# 2018-01-01 02:00:00    267.0      0.0    98.47      0.0      0.0      0.0
# 2018-01-01 03:00:00    262.0      0.0    98.43      0.0      0.0      0.0
# 2018-01-01 04:00:00    268.0      0.0    98.35      0.0      0.0      0.0
#
#                      Pom_PZR  Pom_SOL  Pom_ZRN  Pom_ZYD           date_hour
# date_hour
# 2018-01-01 00:00:00      2.9     0.41    17.65     3.24 2018-01-01 00:00:00
# 2018-01-01 01:00:00      3.7     0.36    17.42     3.84 2018-01-01 01:00:00
# 2018-01-01 02:00:00      3.4     0.38    17.45    56.74 2018-01-01 02:00:00
# 2018-01-01 03:00:00     20.6     0.36    17.19    66.04 2018-01-01 03:00:00
# 2018-01-01 04:00:00    137.4     0.38    16.99   112.72 2018-01-01 04:00:00

# %%
warnings.filterwarnings("ignore")
df_res=check_missing_datetime_index(df_pt,'H')
df_res
# Out:
# There are no missing dates in the datetime index.

# %%
info_dataset(df_pt)
# Out:
# Count rows: (42360, 41)
# Min date: 2018-01-01 00:00:00
# Max date: 2022-10-31 23:00:00

# %% [markdown]
# # Prepare g_wiatr

# %%
df_g_wiatr.columns=['Data','Godzina','gen_wiatr','gen_fotowolt']
col=['gen_wiatr','gen_fotowolt']
df_g_wiatr=prepare_column(df_g_wiatr,col)
df_g_wiatr=prepare_index(df_g_wiatr,"%Y-%m-%d")
df_g_wiatr.head()
# Out:
# There are missing dates in the datetime index.
# count row with missing index: 5
#                      gen_wiatr  gen_fotowolt
# date_hour
# 2018-01-01 00:00:00   3893.613           0.0
# 2018-01-01 01:00:00   3828.699           0.0
# 2018-01-01 02:00:00   3982.800           0.0
# 2018-01-01 03:00:00   4083.114           0.0
# 2018-01-01 04:00:00   4089.188           0.0

# %%
info_dataset(df_g_wiatr)
# Out:
# Count rows: (42360, 2)
# Min date: 2018-01-01 00:00:00
# Max date: 2022-10-31 23:00:00

# %% [markdown]
# # Prepare i_net

# %%
df_i_net.columns=['Data','Czas od','Czas do','energia_frr_export','energia_frr_import','frr_export','frr_import','frr_export_eur','frr_import_eur']
for x in ['energia_frr_export','energia_frr_import','frr_export','frr_import','frr_export_eur','frr_import_eur']:
    df_i_net[x]=np.where(df_i_net[x].isna(),0,df_i_net[x].str.replace(',','.').astype(float))
df_i_net.index=pd.to_datetime(df_i_net['Data']+' '+df_i_net['Czas od'])
df_i_net=df_i_net.resample('H').sum()
df_i_net.head()
# Out:
#                      energia_frr_export  energia_frr_import  frr_export  \
# 2020-02-18 00:00:00                 0.0                 0.0      284.96
# 2020-02-18 01:00:00                 0.0                 0.0      284.96
# 2020-02-18 02:00:00                 0.0                 0.0      284.88
# 2020-02-18 03:00:00                 0.0                 0.0      284.96
# 2020-02-18 04:00:00                 0.0                 0.0      284.96
#
#                      frr_import  frr_export_eur  frr_import_eur
# 2020-02-18 00:00:00      284.96          66.712          66.712
# 2020-02-18 01:00:00      284.96          66.712          66.712
# 2020-02-18 02:00:00      284.88          66.696          66.696
# 2020-02-18 03:00:00      284.96          66.712          66.712
# 2020-02-18 04:00:00      284.96          66.712          66.712

# %%
warnings.filterwarnings("ignore")
df_res=check_missing_datetime_index(df_i_net,'H')
df_res
# Out:
# There are no missing dates in the datetime index.

# %%
info_dataset(df_i_net)
# Out:
# Count rows: (23688, 6)
# Min date: 2020-02-18 00:00:00
# Max date: 2022-10-31 23:00:00

# %% [markdown]
# # Prepare w_kse

# %%
col=df_w_kse.drop(['Data','Godzina'],axis=1).columns.to_list()
df_w_kse=prepare_column(df_w_kse,col)
df_w_kse=prepare_index(df_w_kse,"%Y-%m-%d")
df_w_kse.head()
# Out:
# There are missing dates in the datetime index.
# count row with missing index: 9
#                      Krajowe zapotrzebowanie na moc  \
# date_hour
# 2018-01-01 00:00:00                       14978.538
# 2018-01-01 01:00:00                       14397.650
# 2018-01-01 02:00:00                       13789.463
# 2018-01-01 03:00:00                       13434.450
# 2018-01-01 04:00:00                       13285.238
#
#                      Sumaryczna generacja JWCD  Generacja PI  Generacja IRZ  \
# date_hour
# 2018-01-01 00:00:00                   6227.750        33.750            0.0
# 2018-01-01 01:00:00                   6046.013        -0.200            0.0
# 2018-01-01 02:00:00                   5713.750       -65.313            0.0
# 2018-01-01 03:00:00                   5540.725       -91.388            0.0
# 2018-01-01 04:00:00                   5685.225      -250.463            0.0
#
#                      Sumaryczna generacja nJWCD  \
# date_hour
# 2018-01-01 00:00:00                    8611.925
# 2018-01-01 01:00:00                    8430.263
# 2018-01-01 02:00:00                    8573.775
# 2018-01-01 03:00:00                    8664.188
# 2018-01-01 04:00:00                    8672.025
#
#                      Krajowe saldo wymiany miêdzysystemowej równoleg³ej  \
# date_hour
# 2018-01-01 00:00:00                                             162.950
# 2018-01-01 01:00:00                                             -19.500
# 2018-01-01 02:00:00                                               4.063
# 2018-01-01 03:00:00                                             -12.013
# 2018-01-01 04:00:00                                              41.875
#
#                      Krajowe saldo wymiany miêdzysystemowej nierównoleg³ej
# date_hour
# 2018-01-01 00:00:00                                                -17.313
# 2018-01-01 01:00:00                                                -45.638
# 2018-01-01 02:00:00                                               -436.950
# 2018-01-01 03:00:00                                               -664.763
# 2018-01-01 04:00:00                                               -863.625

# %%
info_dataset(df_w_kse)
# Out:
# Count rows: (42360, 7)
# Min date: 2018-01-01 00:00:00
# Max date: 2022-10-31 23:00:00

# %% [markdown]
# # Prepare w_ubytki

# %%
df_w_ubytki.columns=['Data','Godzina','Elektrownia','Kod JW','elektro','siec','dostep']
df_w_ubytki['kod_jw']='ubytki_'+df_w_ubytki['Kod JW'].map(lambda x: x[:3])
col=['elektro','siec','dostep']
df_w_ubytki=prepare_column(df_w_ubytki,col)

df_ptu=pd.pivot_table(
    df_w_ubytki, 
    values=['elektro','siec','dostep'], 
    index=['Data','Godzina'],
    columns='kod_jw', 
    aggfunc=np.sum, fill_value=0, margins=False).reset_index()
df_ptu.columns = ['_'.join(str(s).strip() for s in col if s) for col in df_ptu.columns ]

df_ptu=prepare_index(df_ptu,"%Y%m%d")
df_ptu.head()
# Out:
# There are missing dates in the datetime index.
# count row with missing index: 5
#                      dostep_ubytki_ADM  dostep_ubytki_BEL  dostep_ubytki_DOD  \
# date_hour
# 2018-01-01 00:00:00                0.0                0.0                0.0
# 2018-01-01 01:00:00                0.0                0.0                0.0
# 2018-01-01 02:00:00                0.0                0.0                0.0
# 2018-01-01 03:00:00                0.0                0.0                0.0
# 2018-01-01 04:00:00                0.0                0.0                0.0
#
#                      dostep_ubytki_JW2  dostep_ubytki_JW3  dostep_ubytki_KAR  \
# date_hour
# 2018-01-01 00:00:00                0.0                0.0              125.0
# 2018-01-01 01:00:00                0.0                0.0              125.0
# 2018-01-01 02:00:00                0.0                0.0              125.0
# 2018-01-01 03:00:00                0.0                0.0              125.0
# 2018-01-01 04:00:00                0.0                0.0              125.0
#
#                      dostep_ubytki_KOZ  dostep_ubytki_LGA  dostep_ubytki_LZA  \
# date_hour
# 2018-01-01 00:00:00                0.0                0.0              140.0
# 2018-01-01 01:00:00                0.0                0.0              140.0
# 2018-01-01 02:00:00                0.0                0.0                0.0
# 2018-01-01 03:00:00                0.0                0.0                0.0
# 2018-01-01 04:00:00                0.0                0.0                0.0
#
#                      dostep_ubytki_OPL  dostep_ubytki_OSB  dostep_ubytki_PAT  \
# date_hour
# 2018-01-01 00:00:00                0.0                0.0                0.0
# 2018-01-01 01:00:00                0.0                0.0                0.0
# 2018-01-01 02:00:00                0.0                0.0                0.0
# 2018-01-01 03:00:00                0.0                0.0                0.0
# 2018-01-01 04:00:00                0.0                0.0                0.0
#
#                      dostep_ubytki_PLO  dostep_ubytki_POL  dostep_ubytki_RYB  \
# date_hour
# 2018-01-01 00:00:00                0.0                0.0                0.0
# 2018-01-01 01:00:00                0.0                0.0                0.0
# 2018-01-01 02:00:00                0.0                0.0                0.0
# 2018-01-01 03:00:00                0.0                0.0                0.0
# 2018-01-01 04:00:00                0.0                0.0                0.0
#
#                      dostep_ubytki_SIA  dostep_ubytki_STW  dostep_ubytki_TUR  \
# date_hour
# 2018-01-01 00:00:00                0.0                0.0                0.0
# 2018-01-01 01:00:00                0.0                0.0                0.0
# 2018-01-01 02:00:00                0.0                0.0                0.0
# 2018-01-01 03:00:00                0.0                0.0                0.0
# 2018-01-01 04:00:00                0.0                0.0                0.0
#
#                      dostep_ubytki_WLC  dostep_ubytki_WZE  elektro_ubytki_ADM  \
# date_hour
# 2018-01-01 00:00:00                0.0                0.0                 0.0
# 2018-01-01 01:00:00                0.0                0.0                 0.0
# 2018-01-01 02:00:00                0.0                0.0                 0.0
# 2018-01-01 03:00:00                0.0                0.0                 0.0
# 2018-01-01 04:00:00                0.0                0.0                 0.0
#
#                      elektro_ubytki_BEL  elektro_ubytki_DOD  \
# date_hour
# 2018-01-01 00:00:00               370.0                 0.0
# 2018-01-01 01:00:00               370.0                 0.0
# 2018-01-01 02:00:00               370.0                 0.0
# 2018-01-01 03:00:00               370.0                 0.0
# 2018-01-01 04:00:00               370.0                 0.0
#
#                      elektro_ubytki_JW2  elektro_ubytki_JW3  \
# date_hour
# 2018-01-01 00:00:00                 0.0                 0.0
# 2018-01-01 01:00:00                 0.0                 0.0
# 2018-01-01 02:00:00                 0.0                 0.0
# 2018-01-01 03:00:00                 0.0                 0.0
# 2018-01-01 04:00:00                 0.0                 0.0
#
#                      elektro_ubytki_KAR  elektro_ubytki_KOZ  \
# date_hour
# 2018-01-01 00:00:00                87.0              1863.0
# 2018-01-01 01:00:00                87.0              1863.0
# 2018-01-01 02:00:00                87.0              1863.0
# 2018-01-01 03:00:00                87.0              1863.0
# 2018-01-01 04:00:00                87.0              1863.0
#
#                      elektro_ubytki_LGA  elektro_ubytki_LZA  \
# date_hour
# 2018-01-01 00:00:00               460.0                85.0
# 2018-01-01 01:00:00               460.0                85.0
# 2018-01-01 02:00:00               460.0               225.0
# 2018-01-01 03:00:00               460.0               225.0
# 2018-01-01 04:00:00               460.0               225.0
#
#                      elektro_ubytki_OPL  elektro_ubytki_OSB  \
# date_hour
# 2018-01-01 00:00:00                 0.0                 0.0
# 2018-01-01 01:00:00                 0.0                 0.0
# 2018-01-01 02:00:00                 0.0                 0.0
# 2018-01-01 03:00:00                 0.0                 0.0
# 2018-01-01 04:00:00                 0.0                 0.0
#
#                      elektro_ubytki_PAT  elektro_ubytki_PLO  \
# date_hour
# 2018-01-01 00:00:00               200.0               630.0
# 2018-01-01 01:00:00               200.0               630.0
# 2018-01-01 02:00:00               200.0               630.0
# 2018-01-01 03:00:00               200.0               630.0
# 2018-01-01 04:00:00               200.0               630.0
#
#                      elektro_ubytki_POL  elektro_ubytki_RYB  \
# date_hour
# 2018-01-01 00:00:00               242.0               450.0
# 2018-01-01 01:00:00               242.0               450.0
# 2018-01-01 02:00:00               242.0               450.0
# 2018-01-01 03:00:00               242.0               450.0
# 2018-01-01 04:00:00               242.0               450.0
#
#                      elektro_ubytki_SIA  elektro_ubytki_STW  \
# date_hour
# 2018-01-01 00:00:00               276.0                 0.0
# 2018-01-01 01:00:00               276.0                 0.0
# 2018-01-01 02:00:00               276.0                 0.0
# 2018-01-01 03:00:00               276.0                 0.0
# 2018-01-01 04:00:00               276.0                 0.0
#
#                      elektro_ubytki_TUR  elektro_ubytki_WLC  \
# date_hour
# 2018-01-01 00:00:00               235.0               485.0
# 2018-01-01 01:00:00               235.0               485.0
# 2018-01-01 02:00:00               235.0               485.0
# 2018-01-01 03:00:00               235.0               485.0
# 2018-01-01 04:00:00               235.0               485.0
#
#                      elektro_ubytki_WZE  siec_ubytki_ADM  siec_ubytki_BEL  \
# date_hour
# 2018-01-01 00:00:00                 0.0              0.0              0.0
# 2018-01-01 01:00:00                 0.0              0.0              0.0
# 2018-01-01 02:00:00                 0.0              0.0              0.0
# 2018-01-01 03:00:00                 0.0              0.0              0.0
# 2018-01-01 04:00:00                 0.0              0.0              0.0
#
#                      siec_ubytki_DOD  siec_ubytki_JW2  siec_ubytki_JW3  \
# date_hour
# 2018-01-01 00:00:00              0.0              0.0              0.0
# 2018-01-01 01:00:00              0.0              0.0              0.0
# 2018-01-01 02:00:00              0.0              0.0              0.0
# 2018-01-01 03:00:00              0.0              0.0              0.0
# 2018-01-01 04:00:00              0.0              0.0              0.0
#
#                      siec_ubytki_KAR  siec_ubytki_KOZ  siec_ubytki_LGA  \
# date_hour
# 2018-01-01 00:00:00              0.0              0.0              0.0
# 2018-01-01 01:00:00              0.0              0.0              0.0
# 2018-01-01 02:00:00              0.0              0.0              0.0
# 2018-01-01 03:00:00              0.0              0.0              0.0
# 2018-01-01 04:00:00              0.0              0.0              0.0
#
#                      siec_ubytki_LZA  siec_ubytki_OPL  siec_ubytki_OSB  \
# date_hour
# 2018-01-01 00:00:00              0.0              0.0              0.0
# 2018-01-01 01:00:00              0.0              0.0              0.0
# 2018-01-01 02:00:00              0.0              0.0              0.0
# 2018-01-01 03:00:00              0.0              0.0              0.0
# 2018-01-01 04:00:00              0.0              0.0              0.0
#
#                      siec_ubytki_PAT  siec_ubytki_PLO  siec_ubytki_POL  \
# date_hour
# 2018-01-01 00:00:00              0.0              0.0              0.0
# 2018-01-01 01:00:00              0.0              0.0              0.0
# 2018-01-01 02:00:00              0.0              0.0              0.0
# 2018-01-01 03:00:00              0.0              0.0              0.0
# 2018-01-01 04:00:00              0.0              0.0              0.0
#
#                      siec_ubytki_RYB  siec_ubytki_SIA  siec_ubytki_STW  \
# date_hour
# 2018-01-01 00:00:00              0.0              0.0              0.0
# 2018-01-01 01:00:00              0.0              0.0              0.0
# 2018-01-01 02:00:00              0.0              0.0              0.0
# 2018-01-01 03:00:00              0.0              0.0              0.0
# 2018-01-01 04:00:00              0.0              0.0              0.0
#
#                      siec_ubytki_TUR  siec_ubytki_WLC  siec_ubytki_WZE
# date_hour
# 2018-01-01 00:00:00              0.0              0.0              0.0
# 2018-01-01 01:00:00              0.0              0.0              0.0
# 2018-01-01 02:00:00              0.0              0.0              0.0
# 2018-01-01 03:00:00              0.0              0.0              0.0
# 2018-01-01 04:00:00              0.0              0.0              0.0

# %%
info_dataset(df_ptu)
# Out:
# Count rows: (42360, 60)
# Min date: 2018-01-01 00:00:00
# Max date: 2022-10-31 23:00:00

# %% [markdown]
# # Prepare w_wym

# %%
col=df_w_wym.drop(['Data','Godzina'],axis=1).columns.to_list()
df_w_wym=prepare_column(df_w_wym,col)
df_w_wym=prepare_index(df_w_wym,"%Y%m%d")
df_w_wym.head()
# Out:
# There are missing dates in the datetime index.
# count row with missing index: 5
#                      CEPS_EXP  CEPS_IMP  SEPS_EXP  SEPS_IMP  50HzT_EXP  \
# date_hour
# 2018-01-01 00:00:00    -616.4       4.0    -348.8       0.0        0.0
# 2018-01-01 01:00:00    -719.7       0.0    -431.6       0.0        0.0
# 2018-01-01 02:00:00    -735.3       0.0    -431.7       0.0        0.0
# 2018-01-01 03:00:00    -819.8       0.4    -424.2       0.0        0.0
# 2018-01-01 04:00:00    -834.0       1.6    -435.4       0.0        0.0
#
#                      50HzT_IMP  SVK_EXP  SVK_IMP  UA_EXP  UA_IMP  LIT_EXP  \
# date_hour
# 2018-01-01 00:00:00    1117.80     0.00      0.0     0.0     0.0     0.00
# 2018-01-01 01:00:00    1130.55    -3.74      0.0     0.0     0.0    -2.35
# 2018-01-01 02:00:00    1203.90  -173.49      0.0     0.0     0.0  -232.46
# 2018-01-01 03:00:00    1240.05  -249.40      0.0     0.0     0.0  -377.81
# 2018-01-01 04:00:00    1259.85  -371.58      0.0     0.0     0.0  -466.60
#
#                      LIT_IMP
# date_hour
# 2018-01-01 00:00:00      0.0
# 2018-01-01 01:00:00      0.0
# 2018-01-01 02:00:00      0.0
# 2018-01-01 03:00:00      0.0
# 2018-01-01 04:00:00      0.0

# %%
info_dataset(df_w_wym)
# Out:
# Count rows: (42360, 12)
# Min date: 2018-01-01 00:00:00
# Max date: 2022-10-31 23:00:00

# %% [markdown]
# # Prepare z_kse

# %%
df_z_kse.columns=['Data','Godzina','demand_forecast','demand_fact']
col=['demand_fact']
df_z_kse=prepare_column(df_z_kse,col)
df_z_kse=prepare_index(df_z_kse,"%Y%m%d")
df_z_kse.head()
# Out:
# There are missing dates in the datetime index.
# count row with missing index: 5
#                      demand_forecast  demand_fact
# date_hour
# 2017-12-31 00:00:00          15600.0    15280.925
# 2017-12-31 01:00:00          14800.0    14513.975
# 2017-12-31 02:00:00          14400.0    14086.700
# 2017-12-31 03:00:00          14300.0    13818.150
# 2017-12-31 04:00:00          14300.0    13792.450

# %%
info_dataset(df_z_kse)
# Out:
# Count rows: (42360, 2)
# Min date: 2017-12-31 00:00:00
# Max date: 2022-10-30 23:00:00

# %% [markdown]
# # Prepare weather

# %%
df_weather_ml=pd.read_parquet(f'{PATH_TGE}weather_ml.parquet')

# %%
def create_datetime_weather(y,m,d,h):
    return  pd.to_datetime(str(y) + "/" + str(m) + "/" + str(d)) + timedelta(hours=h)

df_weather_ml['date_hour']=df_weather_ml.apply(lambda x:create_datetime_weather(x.year,x.month,x.day,x.hour), axis=1)
df_weather_ml.index=df_weather_ml['date_hour']
df_weather_ml.drop(['date_hour'],axis=1,inplace=True)
df_weather_ml.head()
# Out:
#                      year  month  day  hour    Main            Description  \
# date_hour
# 2018-01-01 00:00:00  2018      1    1     0  Clouds  broken clouds: 51-84%
# 2018-01-01 01:00:00  2018      1    1     1   Clear              clear sky
# 2018-01-01 02:00:00  2018      1    1     2   Clear              clear sky
# 2018-01-01 03:00:00  2018      1    1     3   Clear              clear sky
# 2018-01-01 04:00:00  2018      1    1     4    Mist                   mist
#
#                      wday  wind_deg  clouds   ID  wind_speed  dew_point  \
# date_hour
# 2018-01-01 00:00:00     0       220      75  803        2.10       5.52
# 2018-01-01 01:00:00     0         0       0  800        1.03       6.31
# 2018-01-01 02:00:00     0         0       0  800        0.51       4.45
# 2018-01-01 03:00:00     0         0       0  800        0.51       5.26
# 2018-01-01 04:00:00     0        50       0  701        2.10       5.37
#
#                      humidity  feels_like  yday  pressure  temp
# date_hour
# 2018-01-01 00:00:00        86        6.44     1      1008  7.71
# 2018-01-01 01:00:00        93        7.37     1      1007  7.37
# 2018-01-01 02:00:00        86        6.62     1      1007  6.62
# 2018-01-01 03:00:00        93        6.31     1      1007  6.31
# 2018-01-01 04:00:00       100        3.70     1      1006  5.37

# %%
warnings.filterwarnings("ignore")
df_res=check_missing_datetime_index_hour(df_weather_ml)
df_res
# Out:
# There are no missing dates in the datetime index.

# %%
info_dataset(df_weather_ml)
# Out:
# Count rows: (44689, 17)
# Min date: 2018-01-01 00:00:00
# Max date: 2023-02-06 00:00:00

# %% [markdown]
# # SAVE Datasets

# %%
df_tge.to_parquet(f'{PATH_TGE}ml_tge.parquet')
dfbm.to_parquet(f'{PATH_TGE}ml_b_moc.parquet')
df_pt.to_parquet(f'{PATH_TGE}ml_g_moc.parquet')
df_g_wiatr.to_parquet(f'{PATH_TGE}ml_g_wiatr.parquet')
df_ptu.to_parquet(f'{PATH_TGE}ml_w_ubytki.parquet')
df_w_wym.to_parquet(f'{PATH_TGE}ml_w_wym.parquet')
df_z_kse.to_parquet(f'{PATH_TGE}ml_z_kse.parquet')
df_w_kse.to_parquet(f'{PATH_TGE}ml_w_kse.parquet')
df_i_net.to_parquet(f'{PATH_TGE}ml_i_net.parquet')
df_weather_ml.to_parquet(f'{PATH_TGE}ml_weather.parquet')
