# %%
import os
import time
import zipfile
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 300)
pd.set_option('display.max_colwidth', None)

# %%
PATH = "../../data/tge/"

# %%
# %%time
df_b_moc=pd.read_parquet(f'{PATH}b_moc.parquet')
df_g_moc=pd.read_parquet(f'{PATH}g_moc.parquet')
df_g_wiatr=pd.read_parquet(f'{PATH}g_wiatr.parquet')
df_i_net=pd.read_parquet(f'{PATH}i_net.parquet')
df_tge=pd.read_parquet(f'{PATH}tge.parquet')
df_w_kse=pd.read_parquet(f'{PATH}w_kse.parquet')
df_w_ubytki=pd.read_parquet(f'{PATH}w_ubytki.parquet')
df_w_wym=pd.read_parquet(f'{PATH}w_wym.parquet')
df_z_kse=pd.read_parquet(f'{PATH}z_kse.parquet')
df_weather=pd.read_parquet(f'{PATH}weather_ml.parquet')
# Out:
# CPU times: total: 1.91 s
# Wall time: 810 ms

# %% [markdown]
# target: df_tge['fixing_1_kurs']

# %%
#df_weather[['year','month','day']].drop_duplicates().groupby(['year','month']).count()

# %%
df_tge
# Out:
#              date  czas  fixing_1_kurs  fixing_1_wolumen  fixing_2_kurs  \
# 0      2022-10-31     1         550.00            1529.9         580.08
# 1      2022-10-31     2         511.79            1785.3         504.51
# 2      2022-10-31     3         499.82            1864.9         495.80
# 3      2022-10-31     4         464.30            1931.1         483.15
# 4      2022-10-31     5         464.30            1882.3         501.09
# ...           ...   ...            ...               ...            ...
# 29331  2019-06-28    20         236.23            2194.8         255.01
# 29332  2019-06-28    21         239.31            2262.3         254.98
# 29333  2019-06-28    22         239.31            2359.2         254.61
# 29334  2019-06-28    23         229.00            1995.7         228.63
# 29335  2019-06-28    24         201.12            1687.3         224.31
#
#        fixing_2_wolumen  notowania_kurs  notowania_wolumen
# ...

# %%
df_tge.query('date=="2022-01-05"')
# Out:
#             date  czas  fixing_1_kurs  fixing_1_wolumen  fixing_2_kurs  \
# 7178  2022-01-05     1         431.36            2278.7         449.55
# 7179  2022-01-05     2         415.15            2605.7         424.29
# 7180  2022-01-05     3         409.40            2609.5         415.48
# 7181  2022-01-05     4         415.15            2650.7         406.11
# 7182  2022-01-05     5         422.01            2666.1         407.80
# 7183  2022-01-05     6         428.00            2607.3         409.80
# 7184  2022-01-05     7         530.00            2788.5         443.17
# 7185  2022-01-05     8         552.01            2679.5         506.23
# 7186  2022-01-05     9         625.01            2857.3         625.02
# 7187  2022-01-05    10         698.50            2759.9         727.65
# 7188  2022-01-05    11         698.00            2481.5         799.55
# 7189  2022-01-05    12         698.50            2640.8         810.14
# ...

# %%
df_g_moc
# Out:
#          Doba  Data publikacji       Kod          Nazwa  Tryb pracy        1  \
# 0    20220101   20220102122138  BEL 2-02  Be³chatów B02   Generacja    0,000
# 1    20220101   20220102122138  BEL 2-03  Be³chatów B03   Generacja  199,400
# 2    20220101   20220102122138  BEL 2-04  Be³chatów B04   Generacja    0,000
# 3    20220101   20220102122138  BEL 2-05  Be³chatów B05   Generacja  200,700
# 4    20220101   20220102122138  BEL 4-06  Be³chatów B06   Generacja  213,230
# ..        ...              ...       ...            ...         ...      ...
# 710  20221030   20221031125412  ZYD 1-01       ydowo H1  Pompowanie    0,000
# 711  20221030   20221031125412  ZYD 1-02       ydowo H2   Generacja    0,000
# 712  20221030   20221031125412  ZYD 1-02       ydowo H2  Pompowanie   59,790
# 713  20221030   20221031125412  ZYD 1-03       ydowo H3   Generacja    0,000
# 714  20221030   20221031125412  ZYD 1-03       ydowo H3  Pompowanie    0,070
#
# ...
